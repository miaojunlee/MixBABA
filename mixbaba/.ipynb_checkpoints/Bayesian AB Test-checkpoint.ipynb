# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import beta_utils
from scipy.stats import beta
from beta_utils import calc_prob_between
import statsmodels
from statsmodels.stats.proportion import proportions_ztest, proportion_confint
sns.set()

# %%
pd.set_option('display.max_row', None)
pd.set_option('display.max_column',None)

# %% [markdown]
# ### Bayesian Approach

# %%
from scipy.stats import beta
import numpy as np
# from calc_prob import calc_prob_between
from beta_utils import calc_prob_between

#This is the known data: imporessions and conversions for the Control and Test set
imps_ctrl,convs_ctrl=6280,294
imps_test, convs_test=6539,235

#here we create the Beta functions for the two sets
a_C, b_C = convs_ctrl+1, imps_ctrl-convs_ctrl+1
beta_C = beta(a_C, b_C)
a_T, b_T = convs_test+1, imps_test-convs_test+1
beta_T = beta(a_T, b_T)

#calculating the lift
lift=(beta_T.mean()-beta_C.mean())/beta_C.mean()

#calculating the probability for Test to be better than Control
prob=calc_prob_between(beta_T, beta_C)

print (f"Test option lift Conversion Rates by {lift*100:2.2f}% with {prob*100:2.1f}% probability.")
#output: Test option lift Conversion Rates by 59.68% with 98.2% probability.
# Out:
# Test option lift Conversion Rates by -23.17% with 0.1% probability.

# %% [markdown]
# ## Frequentist T-Test

# %%
import statsmodels
from statsmodels.stats.proportion import proportions_ztest, proportion_confint

# %%
print(np.array(proportion_confint(30, 16500, alpha=0.05, method='binom_test'))*100)
print(np.array(proportion_confint(50, 17000, alpha=0.05, method='binom_test'))*100)
# Out:
# [0.1263515  0.25963385]
# [0.2218592  0.38734966]

# %%
convs_ctrl=846
imps_ctrl=31276

convs_test=900
imps_test=31172

count = np.array([convs_ctrl, convs_test])
nobs = np.array([imps_ctrl, imps_test])

stat, pval = proportions_ztest(count, nobs)

lift = (convs_test/imps_test - convs_ctrl/imps_ctrl)/(convs_ctrl/imps_ctrl)

# print(convs_test/imps_test)
# print(convs_ctrl/imps_ctrl)

# print("pvalue:",'{0:0.3f}'.format(pval))

print (f"Test option lift Conversion Rates by {lift*100:2.2f}%", "with pvalue:", '{0:0.3f}'.format(pval))
# Out:
# 0.028872064673424867
# 0.0270494948203095
# Test option lift Conversion Rates by 6.74% with pvalue: 0.167

# %% [markdown]
# ## Random Functions

# %%
# Return random floats in the half-open interval [0.0, 1.0). 
print(np.random.random())
# Out:
# 0.3648505976601081

# %%
# Draw random samples from a normal (Gaussian) distribution.
# numpy.random.normal(loc=0.0, scale=1.0, size=None)

noise=[]
for i in range(10000):
    noise.append(np.random.normal())
    
plt.hist(noise);

# %%
noise=[]
for i in range(1000):
    noise.append(np.random.normal(loc=0, scale=0.03))
    
plt.hist(noise);

# %%
# Generate Four Random Integers Between ranges
# Return random integers from the “discrete uniform” distribution of the specified dtype in the “half-open” interval [low, high). If high is None (the default), then results are from [0, low).

np.int(np.random.randint(low=100, high=500, size=1))
# Out:
# 196

# %% [markdown]
# ## Simulations

# %%
np.random.seed(234)
result=[]

for x in range(2000):
    
    #initialize in the range of [100, 50000), this follows the “discrete uniform” distribution
    imps_ctrl=np.int(np.random.randint(low=100, high=50000, size=1)) 
    
    #initialize CR follows normal distribution with mean at 5% and standard deviation of 2%
    cr=np.random.normal(loc=0.05, scale=0.02)
    
    #conversion=clicks * simulated cr; if less than 0, use small number 
    if cr<0: cr=0.001
    convs_ctrl = np.int(np.floor(imps_ctrl*cr))
    
    #initialize the treatment clicks based on control clicks but with variation
    imps_test=np.int(imps_ctrl*(1+np.random.normal(loc=0, scale=0.06)))
    convs_test=np.int(convs_ctrl*(1+np.random.normal(loc=0, scale=0.03)))
    test_cr=convs_test/imps_test
    
    a_C, b_C = convs_ctrl+1, imps_ctrl-convs_ctrl+1
    beta_C = beta(a_C, b_C)
    
    a_T, b_T = convs_test+1, imps_test-convs_test+1
    beta_T = beta(a_T, b_T)

    #calculating the lift
    bayesian_lift=(beta_T.mean()-beta_C.mean())/beta_C.mean()
    prob=calc_prob_between(beta_T, beta_C)
    
    count = np.array([convs_ctrl, convs_test])
    nobs = np.array([imps_ctrl, imps_test])

    stat, pval = proportions_ztest(count, nobs)

    freq_lift = (convs_test/imps_test - convs_ctrl/imps_ctrl)/(convs_ctrl/imps_ctrl)
    
    result.append((imps_ctrl, convs_ctrl, cr, imps_test, convs_test, test_cr, 
                   bayesian_lift, prob, 
                   stat, pval, freq_lift))

# %%
df.shape
# Out:
# (100, 11)

# %%
df = pd.DataFrame(result, columns=['Control_Clicks', 'Control_Sale', 'Control_CR',
                                   'Treatment_Clicks', 'Treatment_Sale', 'Treatment_CR', 
                                   'Bayesian_Lift', 'Prob',
                                   'Z-value', 'P-value', 'Freq_Lift'])

# %%
df['Click_Diff']=np.abs(df['Control_Clicks']-df['Treatment_Clicks'])

# %%
plt.hist(df['Click_Diff']);

# %%
df.head(5)
# Out:
#    Control_Clicks  Control_Sale  Control_CR  Treatment_Clicks  Treatment_Sale  \
# 0           31276           846    0.027079             31172             900
# 1           46167          3440    0.074513             48243            3481
# 2           46214          2703    0.058509             40708            2715
# 3           42027           312    0.007437             42137             325
# 4           22654          2260    0.099783             24039            2229
#
#    Treatment_CR  Bayesian_Lift      Prob   Z-value       P-value  Freq_Lift
# 0      0.028872       0.067303  0.916370 -1.381363  1.671674e-01   0.067379
# 1      0.072156      -0.031628  0.082450  1.388698  1.649246e-01  -0.031626
# 2      0.066695       0.140287  1.000000 -4.993444  5.931200e-07   0.140296
# 3      0.007713       0.038815  0.685608 -0.483927  6.284373e-01   0.038947
# 4      0.092724      -0.070531  0.004972  2.578170  9.932518e-03  -0.070541

# %%
df.sort_values(by='Prob', ascending=True).head(100)
# Out:
#       Control_Clicks  Control_Sale  Control_CR  Treatment_Clicks  \
# 1362           41558          2083    0.050136             48234
# 1364           42442          2904    0.068441             49069
# 1696           40222          3158    0.078528             46061
# 470            29789          1058    0.035544             36449
# 283            42543          2645    0.062194             47102
# 260            41770          2567    0.061474             49050
# 410            40956          2138    0.052207             45006
# 927            34806          2276    0.065412             37951
# 1248           46380          3124    0.067367             50079
# 944            45325          2806    0.061924             49855
# 1839           36585          3879    0.106054             39687
# 1489           48940          2826    0.057748             55621
# 737            21780          1772    0.081390             24828
# 1183           43133          3884    0.090060             45241
# 1256           47708          3434    0.071988             50742
# 397            29070          1599    0.055017             32528
# 956            38677          2885    0.074595             43199
# 693            36278          1730    0.047715             40070
# 1936           39514          3609    0.091350             40387
# 20    1.449061e-03  -0.089514        5589
# 1522  1.522775e-03  -0.096636        1836
# 1771  1.613677e-03  -0.105503        2716
# 1318  1.738583e-03  -0.061605        2812
# 1189  2.129899e-03  -0.094343        1896
# 243   2.291962e-03  -0.077177        4895
# 634   2.303828e-03  -0.134723        2074
# 1442  2.409105e-03  -0.074515        2747
# 1615  2.446447e-03  -0.103158        2003
# 736   2.599190e-03  -0.172816        6716
# 1510  2.682409e-03  -0.087342        5868
# 1398  2.871733e-03  -0.083209        4355
# 1710  2.874383e-03  -0.092529        1589
# 797   2.935569e-03  -0.081426         641
# 1052  2.987739e-03  -0.113184        1910
# 1749  3.110357e-03  -0.067917        2984
# 429   3.287194e-03  -0.088126        2188
# 686   3.324227e-03  -0.095060        2909
# 531   3.377667e-03  -0.089145         372
# 1491  3.537734e-03  -0.110760        1524
# 1317  3.663009e-03  -0.090879        1632
# 1718  3.715214e-03  -0.098697        3914
# 1547  3.794689e-03  -0.068005        3289
# 449   4.043200e-03  -0.131782        1604
# 1225  4.076232e-03  -0.118353        2722
# 725   4.245178e-03  -0.066846        3790
# 1306  4.436036e-03  -0.078246        2186

# %%
df[['Bayesian_Lift', 'Freq_Lift']].plot(kind='hist',subplots=True,figsize=(10,8));

# %%
plt.figure(figsize=(8,6))
plt.title('Distribution of Control Clicks', fontsize=15)
plt.hist(df['Control_Clicks']);

# %%
# plt.figure(figsize=(8,6))
# plt.title('Distribution of Control CR & Treatment CR', fontsize=15)
df[['Control_CR', 'Treatment_CR']].plot(kind='hist',subplots=True,figsize=(10,8));

# %%
df['Prob'].corr(df['P-value'])
# Out:
# -0.00761009988095161

# %%
sns.set_style('whitegrid')
sns.lmplot('Prob','P-value',data=df, 
#            hue='Private',
           palette='coolwarm',height=6,aspect=1,fit_reg=True);

# %%
df.sample(frac=0.01)
# Out:
#       Control_Clicks  Control_Sale  Control_CR  Treatment_Clicks  \
# 1813           15738           817    0.051928             15064
# 780             3703           110    0.029958              3636
# 1479           48135          2102    0.043680             46820
# 1415           22287           644    0.028898             22575
# 444            30418          1475    0.048510             30488
# 1178           26327          1526    0.057998             25936
# 503             1382            74    0.053891              1377
# 1223            1449            81    0.056181              1363
# 518            42092          2008    0.047705             46324
# 847            43052          1711    0.039755             41843
# 162            22977          1006    0.043812             24972
# 904            19983          1527    0.076462             19021
# 925            16805          1130    0.067291             18140
# 1747           35923          2272    0.063269             38431
# 882              809            42    0.052340               726
# 846            31271           921    0.029471             30713
# 1685           30676           579    0.018899             30354
# 1444           32401          1876    0.057911             27869
# 1714           38864          3894    0.100210             35388
# 676            23638          1219    0.051583             22611
#
#       Treatment_Sale  Treatment_CR  Bayesian_Lift      Prob   Z-value  \
# 1813             788      0.052310       0.007698  0.562597 -0.156945
# 780              106      0.029153      -0.018283  0.444754  0.140075
# 1479            2149      0.045899       0.051062  0.951695 -1.661566
# 1415             632      0.027996      -0.031124  0.283171  0.573480
# 444             1408      0.046182      -0.047585  0.089880  1.341672
# 1178            1456      0.056138      -0.031458  0.184297  0.899389
# 503               75      0.054466       0.017007  0.542511 -0.106973
# 1223              83      0.060895       0.088931  0.714191 -0.564804
# 518             1992      0.043001      -0.098589  0.000391  3.360876
# 847             1688      0.040341       0.015070  0.671849 -0.444806
# 162             1011      0.040485      -0.075314  0.036173  1.796993
# 904             1541      0.081016       0.060196  0.954204 -1.687094
# 925             1162      0.064057      -0.047375  0.114711  1.201465
# 1747            2393      0.062267      -0.015497  0.290963  0.550086
# 882               41      0.056474       0.088104  0.654914 -0.394219
# 846              986      0.032104       0.089947  0.972000 -1.911295
# 1685             567      0.018680      -0.010302  0.429653  0.177545
# 1444            1899      0.068140       0.176852  1.000000 -5.173209
# 1714            3881      0.109670       0.094554  0.999987 -4.211349
# 676             1200      0.053072       0.029135  0.765950 -0.725245
#
#            P-value  Freq_Lift
# 1813  8.752884e-01   0.007659
# 780   8.886006e-01  -0.018607
# 1479  9.659991e-02   0.051074
# 1415  5.663196e-01  -0.031153
# 444   1.797023e-01  -0.047615
# 1178  3.684456e-01  -0.031488
# 503   9.148101e-01   0.017194
# 1223  5.722072e-01   0.089345
# 518   7.769574e-04  -0.098597
# 847   6.564602e-01   0.015063
# 162   7.233668e-02  -0.075316
# 904   9.158529e-02   0.060208
# 925   2.295709e-01  -0.047360
# 1747  5.822601e-01  -0.015478
# 882   6.934193e-01   0.087794
# 846   5.596673e-02   0.090026
# 1685  8.590800e-01  -0.010337
# 1444  2.301071e-07   0.176872
# 1714  2.538503e-05   0.094559
# 676   4.683017e-01   0.029126

# %% [markdown]
# ## Random Sample

# %%
from sklearn.datasets import make_blobs
from matplotlib import pyplot
from sklearn.datasets import make_moons

# %% [markdown]
# ### Generate Test Data

# %%
import scipy.stats as scs
from src.data import generate_data
import gc

# %%
import scipy.stats as scs
import pandas as pd
# import numpy as np


def generate_data(N_A, N_B, p_A, p_B, days=None, control_label='A',
                  test_label='B'):
    """Returns a pandas dataframe with fake CTR data

    Example:

    Parameters:
        N_A (int): sample size for control group
        N_B (int): sample size for test group
            Note: final sample size may not match N_A provided because the
            group at each row is chosen at random (50/50).
        p_A (float): conversion rate; conversion rate of control group
        p_B (float): conversion rate; conversion rate of test group
        days (int): optional; if provided, a column for 'ts' will be included
            to divide the data in chunks of time
            Note: overflow data will be included in an extra day
        control_label (str)
        test_label (str)

    Returns:
        df (df)
    """

    # initiate empty container
    data = []

    # total amount of rows in the data
    N = N_A + N_B

    # distribute events based on proportion of group size
    group_bern = scs.bernoulli(N_A / (N_A + N_B))

    # initiate bernoulli distributions from which to randomly sample
    A_bern = scs.bernoulli(p_A)
    B_bern = scs.bernoulli(p_B)

    for idx in range(N):
        # initite empty row
        row = {}
        # for 'ts' column
        if days is not None:
            if type(days) == int:
                row['ts'] = idx // (N // days)
            else:
                raise ValueError("Provide an integer for the days parameter.")
        # assign group based on 50/50 probability
        row['group'] = group_bern.rvs()

        if row['group'] == 0:
            # assign conversion based on provided parameters
            row['converted'] = A_bern.rvs()
        else:
            row['converted'] = B_bern.rvs()
        # collect row into data container
        data.append(row)

    # convert data into pandas dataframe
    df = pd.DataFrame(data)

    # transform group labels of 0s and 1s to user-defined group labels
    df['group'] = df['group'].apply(
        lambda x: control_label if x == 0 else test_label)

    return df

# %%
ab_data = generate_data(N_A=150000, N_B=150000, p_A=0.10, p_B=0.12, 
#                         days=7, 
                        control_label='C', test_label='T')

# %%
ab_data.columns
# Out:
# Index(['group', 'converted'], dtype='object')

# %%
ab_data['group'].value_counts()
# Out:
# T    150310
# C    149690
# Name: group, dtype: int64

# %%
ab_summary = ab_data.pivot_table(values='converted', index='group', aggfunc=np.sum)
# add additional columns to the pivot table
ab_summary['total'] = ab_data.pivot_table(values='converted', index='group', aggfunc=lambda x: len(x))
ab_summary['rate'] = ab_data.pivot_table(values='converted', index='group')

ab_summary
# Out:
#        converted   total      rate
# group
# C          14925  149690  0.099706
# T          18003  150310  0.119772

# %%
control_data=ab_data[ab_data['group']=='C']['converted']
treatment_data=ab_data[ab_data['group']=='T']['converted']

# %%
control_data['converted']
# Out:
# 0.09970605918899059

# %%
imps_ctrl=np.int(np.random.randint(low=100, high=50000, size=1))
len(control_data.sample(n=imps_ctrl))
# Out:
# 21853

# %%
del ab_data
gc.collect()
# Out:
# 374

# %%
control_cr=np.random.normal(loc=0.05, scale=0.02)
treatment_cr=control_cr*(1+np.random.normal(loc=0, scale=0.06))
              
print("Simulated Control CR:", control_cr) 
print("Simulated Treatment CR:", treatment_cr)

ab_data = generate_data(N_A=150000, 
                        N_B=150000, 
                        p_A=control_cr, 
                        p_B=treatment_cr, 
#                         days=7, 
                        control_label='C', test_label='T')
# Out:
# Simulated Control CR: 0.045375005830863395
# Simulated Treatment CR: 0.040811156967798225

# %%
ab_summary = ab_data.pivot_table(values='converted', index='group', aggfunc=np.sum)
# add additional columns to the pivot table
ab_summary['total'] = ab_data.pivot_table(values='converted', index='group', aggfunc=lambda x: len(x))
ab_summary['rate'] = ab_data.pivot_table(values='converted', index='group')

ab_summary
# Out:
#        converted   total      rate
# group
# C           6973  150115  0.046451
# T           6022  149885  0.040177

# %%
result=[]

for i in range(2):
#     np.random.seed(i)
    actual_control_cr=np.random.normal(loc=0.05, scale=0.02)
    actual_treatment_cr=control_cr*(1+np.random.normal(loc=0, scale=0.06))
              
    print("Simulated Control CR:", actual_control_cr) 
    print("Simulated Treatment CR:", actual_treatment_cr)

    ab_data = generate_data(N_A=250000, 
                            N_B=250000, 
                            p_A=actual_control_cr, 
                            p_B=actual_treatment_cr, 
#                         days=7, 
                            control_label='C', test_label='T')
    
    print("done generating population")

    for r in range(5):

        imps_ctrl=np.int(np.random.randint(low=100, high=50000, size=1)) 
        convs_ctrl=ab_data[ab_data['group']=='C'].sample(n=imps_ctrl)['converted'].sum()
        sample_control_cr=convs_ctrl/imps_ctrl

        imps_test=np.int(imps_ctrl*(1+np.random.normal(loc=0, scale=0.06)))
        convs_test=ab_data[ab_data['group']=='T'].sample(n=imps_ctrl)['converted'].sum()
        sample_treatment_cr=convs_test/imps_test

        a_C, b_C = convs_ctrl+1, imps_ctrl-convs_ctrl+1
        beta_C = beta(a_C, b_C)
    
        a_T, b_T = convs_test+1, imps_test-convs_test+1
        beta_T = beta(a_T, b_T)

        #calculating the lift
        bayesian_lift=(beta_T.mean()-beta_C.mean())/beta_C.mean()
        prob=calc_prob_between(beta_T, beta_C)

        count = np.array([convs_ctrl, convs_test])
        nobs = np.array([imps_ctrl, imps_test])

        stat, pval = proportions_ztest(count, nobs)

        freq_lift = (convs_test/imps_test - convs_ctrl/imps_ctrl)/(convs_ctrl/imps_ctrl)
    
        result.append((i, actual_control_cr, actual_treatment_cr,
               r, 
               imps_ctrl, convs_ctrl, sample_control_cr, 
               imps_test, convs_test, sample_treatment_cr, 
               bayesian_lift, prob, 
               stat, pval, freq_lift))
        
        r+=1
        print("done with round:", r)
    
    del ab_data
    gc.collect()
# Out:
# Simulated Control CR: 0.07449519208392495
# Simulated Treatment CR: 0.04083682213024927
# done generating population
# done with round: 1
# done with round: 2
# done with round: 3
# done with round: 4
# done with round: 5
# Simulated Control CR: 0.030671855575321313
# Simulated Treatment CR: 0.04170006372468951
# done generating population
# done with round: 1
# done with round: 2
# done with round: 3
# done with round: 4
# done with round: 5

# %%
df = pd.DataFrame(result, columns=['Sample',
                                   'Actual_Control_CR', 'Actual_Treatment_CR',
                                   'Round', 
                                   'Control_Clicks', 'Control_Sale', 'Control_CR',
                                   'Treatment_Clicks', 'Treatment_Sale', 'Treatment_CR', 
                                   'Bayesian_Lift', 'Prob',
                                   'Z-value', 'P-value', 'Freq_Lift'])

# %%
df
# Out:
#    Sample  Actual_Control_CR  Actual_Treatment_CR  Round  Control_Clicks  \
# 0       0           0.074495             0.040837      0           49937
# 1       0           0.074495             0.040837      1           14289
# 2       0           0.074495             0.040837      2            9239
# 3       0           0.074495             0.040837      3            2873
# 4       0           0.074495             0.040837      4           31440
# 5       1           0.030672             0.041700      0           38560
# 6       1           0.030672             0.041700      1           30143
# 7       1           0.030672             0.041700      2           37860
# 8       1           0.030672             0.041700      3           40971
# 9       1           0.030672             0.041700      4           24084
#
#    Control_Sale  Control_CR  Treatment_Clicks  Treatment_Sale  Treatment_CR  \
# 0          3775    0.075595             46498            2028      0.043615
# 1          1110    0.077682             15541             544      0.035004
# 2           680    0.073601              9496             357      0.037595
# 3           241    0.083884              2872             118      0.041086
# 4          2315    0.073632             32591            1320      0.040502
# 5          1183    0.030679             37458            1610      0.042981
# 6           916    0.030388             29791            1229      0.041254
# 7          1143    0.030190             38521            1563      0.040575
# 8          1243    0.030339             43046            1718      0.039911
# 9           698    0.028982             25852             989      0.038256
#
#    Bayesian_Lift          Prob    Z-value       P-value  Freq_Lift
# 0      -0.422919  1.205033e-98  20.867167  1.064590e-96  -0.423049
# 1      -0.548965  2.655178e-59  16.090264  2.985634e-58  -0.549392
# 2      -0.488527  1.024580e-27  10.775471  4.494769e-27  -0.489209
# 3      -0.508093  7.151612e-12   6.701145  2.067922e-11  -0.510203
# 4      -0.449763  2.436374e-74  18.111516  2.585297e-73  -0.449943
# 5       0.400669  1.000000e+00  -9.013843  1.989585e-19   0.400985
# 6       0.357178  1.000000e+00  -7.159611  8.090635e-13   0.357556
# 7       0.343675  1.000000e+00  -7.762798  8.307557e-15   0.343989
# 8       0.315226  1.000000e+00  -7.521267  5.424790e-14   0.315515
# 9       0.319456  1.000000e+00  -5.731907  9.930758e-09   0.320004
